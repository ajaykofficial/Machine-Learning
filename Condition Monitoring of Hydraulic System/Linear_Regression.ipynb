# %% [markdown]
# # Importing modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error,r2_score

# %% [markdown]
# # Importing Data

# %%
df = pd.read_csv(r"C:\Users\ajayk\Desktop\Machine Learning\Condition_Monitoring_of_Hydraulic_System.csv")

# %%
df
# Out:
#       Unnamed: 0         PS1         PS2       PS3       PS4       PS5  \
# 0              0  160.673492  109.466914  1.991475  9.842170  9.728098
# 1              1  160.603320  109.354890  1.976234  9.635142  9.529488
# 2              2  160.347720  109.158845  1.972224  9.530548  9.427949
# 3              3  160.188088  109.064807  1.946575  9.438827  9.337430
# 4              4  160.000472  108.931434  1.922707  9.358762  9.260636
# ...          ...         ...         ...       ...       ...       ...
# 2200        2200  161.227572  109.779581  2.001438  9.972037  9.850361
# 2201        2201  161.206070  109.787481  1.998781  9.966184  9.844854
# 2202        2202  161.192120  109.756174  1.993436  9.964329  9.842628
# 2203        2203  161.208917  109.793884  2.007077  9.968232  9.846690
# 2204        2204  161.217128  109.792177  2.002690  9.973638  9.851949
#
#            FS1        TS1        TS2        TS3        TS4         CE  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'PS1', 'PS2', 'PS3', 'PS4', 'PS5', 'FS1', 'TS1', 'TS2',
#        'TS3', 'TS4', 'CE', 'CP', 'SE', 'y_coolerCondition', 'y_valveCondition',
#        'y_pumpLeak', 'y_hydraulicAcc', 'y_stableFlag'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0         PS1         PS2       PS3       PS4       PS5       FS1  \
# 0           0  160.673492  109.466914  1.991475  9.842170  9.728098  6.709815
# 1           1  160.603320  109.354890  1.976234  9.635142  9.529488  6.715315
# 2           2  160.347720  109.158845  1.972224  9.530548  9.427949  6.718522
# 3           3  160.188088  109.064807  1.946575  9.438827  9.337430  6.720565
# 4           4  160.000472  108.931434  1.922707  9.358762  9.260636  6.690308
#
#          TS1        TS2        TS3        TS4         CE        CP         SE  \
# 0  35.621983  40.978767  38.471017  31.745250  39.601350  1.862750  59.157183
# 1  36.676967  41.532767  38.978967  34.493867  25.786433  1.255550  59.335617
# 2  37.880800  42.442450  39.631950  35.646150  22.218233  1.113217  59.543150
# 3  38.879050  43.403983  40.403383  36.579467  20.459817  1.062150  59.794900
# 4  39.803917  44.332750  41.310550  37.427900  19.787017  1.070467  59.455267
#
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0         PS1         PS2       PS3       PS4       PS5  \
# 2200        2200  161.227572  109.779581  2.001438  9.972037  9.850361
# 2201        2201  161.206070  109.787481  1.998781  9.966184  9.844854
# 2202        2202  161.192120  109.756174  1.993436  9.964329  9.842628
# 2203        2203  161.208917  109.793884  2.007077  9.968232  9.846690
# 2204        2204  161.217128  109.792177  2.002690  9.973638  9.851949
#
#            FS1        TS1        TS2        TS3        TS4         CE  \
# 2200  6.689930  35.313783  40.874800  38.269267  30.404733  46.628517
# 2201  6.692182  35.321600  40.868883  38.268250  30.416233  46.689817
# 2202  6.693277  35.319183  40.875950  38.246367  30.426250  46.472300
# 2203  6.684128  35.324767  40.876067  38.245733  30.414283  46.544967
# 2204  6.692302  35.322233  40.859400  38.248917  30.390800  46.647933
#
#             CP        SE  y_coolerCondition  y_valveCondition  y_pumpLeak  \
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0          PS1          PS2          PS3          PS4  \
# count  2205.000000  2205.000000  2205.000000  2205.000000  2205.000000
# mean   1102.000000   160.485315   109.379906     1.753227     9.163320
# std     636.672993     4.699425     4.986585     0.251902     0.576296
# min       0.000000   155.391547   104.406307     0.840252     8.365800
# 25%     551.000000   158.100195   106.962382     1.729733     8.547239
# 50%    1102.000000   158.960895   107.730169     1.779631     9.115781
# 75%    1653.000000   161.000735   109.421612     1.932047     9.844351
# max    2204.000000   180.922708   131.589089     2.023398     9.978510
#
#                PS5          FS1          TS1          TS2          TS3  \
# count  2205.000000  2205.000000  2205.000000  2205.000000  2205.000000
# mean      9.079363     6.198549    45.424567    50.365979    47.662121
# std       0.549589     1.032883     7.991933     7.396254     7.451888
# ...

# %% [markdown]
# # Assigning values to X and y

# %%
X = df[['PS1', 'PS2', 'PS3', 'PS4', 'PS5', 'FS1', 'TS1', 'TS2', 'TS3', 'TS4', 'CE', 'CP', 'SE']]
y = df[['y_coolerCondition', 'y_valveCondition', 'y_pumpLeak', 'y_hydraulicAcc']]

# %% [markdown]
# # Splitting dataset into train and test

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=0)

# %% [markdown]
# # Displaying values

# %%
X_train
# Out:
#              PS1         PS2       PS3       PS4       PS5       FS1  \
# 572   156.259090  105.109720  1.686528  8.409337  8.359900  6.572717
# 117   157.029422  106.361600  1.729071  8.592279  8.533665  6.601323
# 1161  159.114915  107.267203  1.803048  9.136608  9.051796  6.632630
# 789   158.176940  107.214707  1.786352  8.970626  8.898110  6.634915
# 1322  158.989445  107.983810  1.806357  9.146062  9.061882  6.672445
# ...          ...         ...       ...       ...       ...       ...
# 1033  158.867803  107.103200  1.789223  9.054415  8.976108  6.643458
# 1731  160.771032  109.054252  1.935512  9.880726  9.761596  6.500505
# 763   157.909970  106.973936  1.779226  8.924975  8.852112  6.626108
# 835   158.262197  107.266625  1.803428  8.985091  8.909845  6.636710
# 1653  161.047945  109.579380  2.008050  9.937681  9.819300  6.687085
#
#             TS1        TS2        TS3        TS4         CE        CP  \
# ...

# %%
y_train
# Out:
#       y_coolerCondition  y_valveCondition  y_pumpLeak  y_hydraulicAcc
# 572                   3                80           0             100
# 117                   3               100           0             130
# 1161                 20                73           0             115
# 789                  20               100           0              90
# 1322                 20               100           0             100
# ...                 ...               ...         ...             ...
# 1033                 20                73           0             130
# 1731                100                80           1             130
# 763                  20               100           0              90
# 835                  20               100           0              90
# 1653                100               100           0              90
#
# [1764 rows x 4 columns]

# %%
X_test
# Out:
#              PS1         PS2       PS3       PS4       PS5       FS1  \
# 1747  160.647718  109.422139  1.957377  9.879644  9.761711  6.533342
# 200   156.928997  106.243144  1.725192  8.535125  8.478645  6.603242
# 333   156.821348  106.100606  1.768057  8.509735  8.452485  6.616405
# 2042  161.098415  109.227591  1.991564  9.842049  9.726338  6.686235
# 206   156.975997  106.274665  1.752760  8.532493  8.477292  6.586313
# ...          ...         ...       ...       ...       ...       ...
# 488   172.765863  122.665902  1.068509  8.431605  8.384973  3.267127
# 1175  158.994632  107.480166  1.801477  9.138057  9.056158  6.664957
# 286   156.404905  105.853168  1.690030  8.515130  8.455835  6.350280
# 2010  160.601713  109.158295  1.929946  9.839934  9.725174  6.515223
# 983   158.099953  107.334708  1.752769  9.029740  8.953610  6.469770
#
#             TS1        TS2        TS3        TS4         CE        CP  \
# ...

# %%
y_test
# Out:
#       y_coolerCondition  y_valveCondition  y_pumpLeak  y_hydraulicAcc
# 1747                100               100           1             130
# 200                   3               100           0             130
# 333                   3               100           0             115
# 2042                100                80           0             100
# 206                   3               100           0             130
# ...                 ...               ...         ...             ...
# 488                   3                80           2             100
# 1175                 20                80           0             115
# 286                   3               100           1             130
# 2010                100                90           1             100
# 983                  20               100           1             130
#
# [441 rows x 4 columns]

# %% [markdown]
# #  Fitting the Linear Regression model

# %%
reg = linear_model.LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Making predictions on the test set

# %%
y_pred = reg.predict(X_test)

# %%
y_pred
# Out:
# array([[101.17067762,  99.81254332,   1.09558438, 113.30132301],
#        [  3.19730076,  98.58413539,  -0.15440841, 121.30010659],
#        [  3.39356577, 102.18493869,  -0.13833649, 121.06769408],
#        ...,
#        [  3.48099298,  96.60179895,   1.46142077, 134.5733817 ],
#        [ 98.89841325,  91.04874738,   1.11442903, 110.54224826],
#        [ 19.60603231,  99.82817619,   1.12711116, 104.67916598]])

# %% [markdown]
# #  Evaluating the performance with R2 score, Mean squared error, and Root mean squared error

# %%
score = r2_score(y_pred,y_test)
print("R2 score is: ", score)
print("Mean Squared Error: ", mean_squared_error(y_test,y_pred))
print("Root Mean Squared Error: ", np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2 score is:  0.7397677021250999
# Mean Squared Error:  41.20690212175238
# Root Mean Squared Error:  6.419260247236622

# %% [markdown]
# # Code for y_flag

# %%
X1 = df[['y_coolerCondition', 'y_valveCondition', 'y_pumpLeak', 'y_hydraulicAcc']]
y1 = df[['y_stableFlag']]

# %%
X1
# Out:
#       y_coolerCondition  y_valveCondition  y_pumpLeak  y_hydraulicAcc
# 0                     3               100           0             130
# 1                     3               100           0             130
# 2                     3               100           0             130
# 3                     3               100           0             130
# 4                     3               100           0             130
# ...                 ...               ...         ...             ...
# 2200                100               100           0              90
# 2201                100               100           0              90
# 2202                100               100           0              90
# 2203                100               100           0              90
# 2204                100               100           0              90
#
# [2205 rows x 4 columns]

# %%
y1
# Out:
#       y_stableFlag
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ...            ...
# 2200             0
# 2201             0
# 2202             0
# 2203             0
# 2204             0
#
# [2205 rows x 1 columns]

# %%
X1_train,X1_test,y1_train,y1_test = train_test_split(X1,y1,test_size=0.2,random_state=23)

# %%
X1_train
# Out:
#       y_coolerCondition  y_valveCondition  y_pumpLeak  y_hydraulicAcc
# 1799                100               100           0             115
# 34                    3               100           0             130
# 186                   3               100           0             130
# 1206                 20               100           0             100
# 1699                100                90           2             130
# ...                 ...               ...         ...             ...
# 1512                100               100           0              90
# 1993                100                80           1             100
# 1064                 20               100           0             130
# 742                  20               100           0              90
# 595                   3               100           0             100
#
# [1764 rows x 4 columns]

# %%
y1_train
# Out:
#       y_stableFlag
# 1799             1
# 34               1
# 186              1
# 1206             1
# 1699             0
# ...            ...
# 1512             1
# 1993             0
# 1064             0
# 742              1
# 595              0
#
# [1764 rows x 1 columns]

# %%
X1_test
# Out:
#       y_coolerCondition  y_valveCondition  y_pumpLeak  y_hydraulicAcc
# 1478                100               100           0              90
# 1254                 20                73           1             100
# 604                   3               100           0              90
# 1789                100               100           0             130
# 1110                 20               100           2             115
# ...                 ...               ...         ...             ...
# 1212                 20                73           2             100
# 2146                100               100           1              90
# 1524                100               100           0              90
# 1690                100                80           2             130
# 956                  20                80           2             130
#
# [441 rows x 4 columns]

# %%
y1_test
# Out:
#       y_stableFlag
# 1478             1
# 1254             0
# 604              1
# 1789             0
# 1110             0
# ...            ...
# 1212             0
# 2146             0
# 1524             1
# 1690             0
# 956              0
#
# [441 rows x 1 columns]

# %%
reg_stable_flag = linear_model.LinearRegression()
reg_stable_flag.fit(X1_train,y1_train)
# Out:
# LinearRegression()

# %%
y_pred_stable_flag = reg_stable_flag.predict(X1_test)
y_pred_stable_flag
# Out:
# array([[ 7.19799053e-01],
#        [-1.10570731e-01],
#        [ 7.32802562e-01],
#        [ 6.51590903e-01],
#        [ 2.49815470e-01],
#        [ 4.68854486e-01],
#        [-1.83481589e-01],
#        [ 7.30523596e-01],
#        [ 2.52094435e-01],
#        [ 1.62127480e-04],
#        [ 6.64594412e-01],
#        [ 2.42021895e-01],
#        [-1.59447878e-01],
#        [ 7.02747016e-01],
#        [ 5.73121732e-02],
#        [ 7.19799053e-01],
#        [ 2.07039136e-02],
#        [ 2.64668983e-01],
#        [-2.59517723e-03],
#        [ 2.87409294e-01],
#        [ 1.62127480e-04],
#        [-3.78486894e-01],
#        [ 6.64594412e-01],
#        [ 7.19799053e-01],
#        [ 7.19799053e-01],
#        [-3.78486894e-01],
#        [ 7.30523596e-01],
#        [ 7.30523596e-01],
#        [ 7.30523596e-01],
#        [ 7.13471559e-01],
#        [ 6.62315446e-01],
#        [ 7.30523596e-01],
#        [ 1.10747251e-01],
#        [-1.33869822e-01],
#        [ 4.91675238e-01],
# ...

# %%
score = r2_score(y_pred_stable_flag,y1_test)
print("R2 score is: ", score)
print("Mean Squared Error: ", mean_squared_error(y1_test,y_pred_stable_flag))
print("Root Mean Squared Error: ", np.sqrt(mean_squared_error(y1_test,y_pred_stable_flag)))
# Out:
# R2 score is:  0.05426227776439696
# Mean Squared Error:  0.12127104213566171
# Root Mean Squared Error:  0.3482399203647705
