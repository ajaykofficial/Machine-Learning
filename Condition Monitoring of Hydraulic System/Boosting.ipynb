# %% [markdown]
# # Importing modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.multiclass import OneVsRestClassifier
from sklearn.ensemble import GradientBoostingClassifier
import seaborn as sns
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, roc_auc_score

# %% [markdown]
# # Loading dataset

# %%
df = pd.read_csv(r"C:\Users\ajayk\Desktop\Machine Learning\Condition_Monitoring_of_Hydraulic_System.csv")

# %%
df
# Out:
#       Unnamed: 0         PS1         PS2       PS3       PS4       PS5  \
# 0              0  160.673492  109.466914  1.991475  9.842170  9.728098
# 1              1  160.603320  109.354890  1.976234  9.635142  9.529488
# 2              2  160.347720  109.158845  1.972224  9.530548  9.427949
# 3              3  160.188088  109.064807  1.946575  9.438827  9.337430
# 4              4  160.000472  108.931434  1.922707  9.358762  9.260636
# ...          ...         ...         ...       ...       ...       ...
# 2200        2200  161.227572  109.779581  2.001438  9.972037  9.850361
# 2201        2201  161.206070  109.787481  1.998781  9.966184  9.844854
# 2202        2202  161.192120  109.756174  1.993436  9.964329  9.842628
# 2203        2203  161.208917  109.793884  2.007077  9.968232  9.846690
# 2204        2204  161.217128  109.792177  2.002690  9.973638  9.851949
#
#            FS1        TS1        TS2        TS3        TS4         CE  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'PS1', 'PS2', 'PS3', 'PS4', 'PS5', 'FS1', 'TS1', 'TS2',
#        'TS3', 'TS4', 'CE', 'CP', 'SE', 'y_coolerCondition', 'y_valveCondition',
#        'y_pumpLeak', 'y_hydraulicAcc', 'y_stableFlag'],
#       dtype='object')

# %%
df.describe()
# Out:
#         Unnamed: 0          PS1          PS2          PS3          PS4  \
# count  2205.000000  2205.000000  2205.000000  2205.000000  2205.000000
# mean   1102.000000   160.485315   109.379906     1.753227     9.163320
# std     636.672993     4.699425     4.986585     0.251902     0.576296
# min       0.000000   155.391547   104.406307     0.840252     8.365800
# 25%     551.000000   158.100195   106.962382     1.729733     8.547239
# 50%    1102.000000   158.960895   107.730169     1.779631     9.115781
# 75%    1653.000000   161.000735   109.421612     1.932047     9.844351
# max    2204.000000   180.922708   131.589089     2.023398     9.978510
#
#                PS5          FS1          TS1          TS2          TS3  \
# count  2205.000000  2205.000000  2205.000000  2205.000000  2205.000000
# mean      9.079363     6.198549    45.424567    50.365979    47.662121
# std       0.549589     1.032883     7.991933     7.396254     7.451888
# ...

# %% [markdown]
# # Assigning values to X and y

# %%
X = df[['PS1', 'PS2', 'PS3', 'PS4', 'PS5', 'FS1', 'TS1', 'TS2', 'TS3', 'TS4', 'CE', 'CP', 'SE']]
y = df[['y_coolerCondition', 'y_valveCondition', 'y_pumpLeak', 'y_hydraulicAcc']]

# %%
X
# Out:
#              PS1         PS2       PS3       PS4       PS5       FS1  \
# 0     160.673492  109.466914  1.991475  9.842170  9.728098  6.709815
# 1     160.603320  109.354890  1.976234  9.635142  9.529488  6.715315
# 2     160.347720  109.158845  1.972224  9.530548  9.427949  6.718522
# 3     160.188088  109.064807  1.946575  9.438827  9.337430  6.720565
# 4     160.000472  108.931434  1.922707  9.358762  9.260636  6.690308
# ...          ...         ...       ...       ...       ...       ...
# 2200  161.227572  109.779581  2.001438  9.972037  9.850361  6.689930
# 2201  161.206070  109.787481  1.998781  9.966184  9.844854  6.692182
# 2202  161.192120  109.756174  1.993436  9.964329  9.842628  6.693277
# 2203  161.208917  109.793884  2.007077  9.968232  9.846690  6.684128
# 2204  161.217128  109.792177  2.002690  9.973638  9.851949  6.692302
#
#             TS1        TS2        TS3        TS4         CE        CP  \
# ...

# %%
y
# Out:
#       y_coolerCondition  y_valveCondition  y_pumpLeak  y_hydraulicAcc
# 0                     3               100           0             130
# 1                     3               100           0             130
# 2                     3               100           0             130
# 3                     3               100           0             130
# 4                     3               100           0             130
# ...                 ...               ...         ...             ...
# 2200                100               100           0              90
# 2201                100               100           0              90
# 2202                100               100           0              90
# 2203                100               100           0              90
# 2204                100               100           0              90
#
# [2205 rows x 4 columns]

# %% [markdown]
# # Splitting dataset to train and test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
X_train
# Out:
#              PS1         PS2       PS3       PS4       PS5       FS1  \
# 572   156.259090  105.109720  1.686528  8.409337  8.359900  6.572717
# 117   157.029422  106.361600  1.729071  8.592279  8.533665  6.601323
# 1161  159.114915  107.267203  1.803048  9.136608  9.051796  6.632630
# 789   158.176940  107.214707  1.786352  8.970626  8.898110  6.634915
# 1322  158.989445  107.983810  1.806357  9.146062  9.061882  6.672445
# ...          ...         ...       ...       ...       ...       ...
# 1033  158.867803  107.103200  1.789223  9.054415  8.976108  6.643458
# 1731  160.771032  109.054252  1.935512  9.880726  9.761596  6.500505
# 763   157.909970  106.973936  1.779226  8.924975  8.852112  6.626108
# 835   158.262197  107.266625  1.803428  8.985091  8.909845  6.636710
# 1653  161.047945  109.579380  2.008050  9.937681  9.819300  6.687085
#
#             TS1        TS2        TS3        TS4         CE        CP  \
# ...

# %%
y_train
# Out:
#       y_coolerCondition  y_valveCondition  y_pumpLeak  y_hydraulicAcc
# 572                   3                80           0             100
# 117                   3               100           0             130
# 1161                 20                73           0             115
# 789                  20               100           0              90
# 1322                 20               100           0             100
# ...                 ...               ...         ...             ...
# 1033                 20                73           0             130
# 1731                100                80           1             130
# 763                  20               100           0              90
# 835                  20               100           0              90
# 1653                100               100           0              90
#
# [1764 rows x 4 columns]

# %%
X_test
# Out:
#              PS1         PS2       PS3       PS4       PS5       FS1  \
# 1747  160.647718  109.422139  1.957377  9.879644  9.761711  6.533342
# 200   156.928997  106.243144  1.725192  8.535125  8.478645  6.603242
# 333   156.821348  106.100606  1.768057  8.509735  8.452485  6.616405
# 2042  161.098415  109.227591  1.991564  9.842049  9.726338  6.686235
# 206   156.975997  106.274665  1.752760  8.532493  8.477292  6.586313
# ...          ...         ...       ...       ...       ...       ...
# 488   172.765863  122.665902  1.068509  8.431605  8.384973  3.267127
# 1175  158.994632  107.480166  1.801477  9.138057  9.056158  6.664957
# 286   156.404905  105.853168  1.690030  8.515130  8.455835  6.350280
# 2010  160.601713  109.158295  1.929946  9.839934  9.725174  6.515223
# 983   158.099953  107.334708  1.752769  9.029740  8.953610  6.469770
#
#             TS1        TS2        TS3        TS4         CE        CP  \
# ...

# %%
y_test
# Out:
#       y_coolerCondition  y_valveCondition  y_pumpLeak  y_hydraulicAcc
# 1747                100               100           1             130
# 200                   3               100           0             130
# 333                   3               100           0             115
# 2042                100                80           0             100
# 206                   3               100           0             130
# ...                 ...               ...         ...             ...
# 488                   3                80           2             100
# 1175                 20                80           0             115
# 286                   3               100           1             130
# 2010                100                90           1             100
# 983                  20               100           1             130
#
# [441 rows x 4 columns]

# %% [markdown]
# # Create the Gradient Boosting Classifier

# %%
boosting_cooler = OneVsRestClassifier(GradientBoostingClassifier( random_state=42))
boosting_valve = OneVsRestClassifier(GradientBoostingClassifier( random_state=42))
boosting_pump = OneVsRestClassifier(GradientBoostingClassifier( random_state=42))
boosting_hydraulic = OneVsRestClassifier(GradientBoostingClassifier( random_state=42))

# %% [markdown]
# # Fit each classifier on the corresponding target variable

# %%
boosting_cooler.fit(X_train[['CE', 'CP', 'PS4', 'PS5', 'TS1', 'TS2', 'TS3', 'TS4']], y_train['y_coolerCondition'])
boosting_valve.fit(X_train[['PS2', 'PS3']], y_train['y_valveCondition'])
boosting_pump.fit(X_train[['FS1', 'SE', 'PS1']], y_train['y_pumpLeak'])
boosting_hydraulic.fit(X_train[['PS1', 'PS2', 'PS3', 'SE', 'FS1', 'TS2']], y_train['y_hydraulicAcc'])
# Out:
# OneVsRestClassifier(estimator=GradientBoostingClassifier(random_state=42))

# %% [markdown]
# # Make predictions on the test data for each classifier

# %%
y_pred_cooler = boosting_cooler.predict(X_test[['CE', 'CP', 'PS4', 'PS5', 'TS1', 'TS2', 'TS3', 'TS4']])
y_pred_valve = boosting_valve.predict(X_test[['PS2', 'PS3']])
y_pred_pump = boosting_pump.predict(X_test[['FS1', 'SE', 'PS1']])
y_pred_hydraulic = boosting_hydraulic.predict(X_test[['PS1', 'PS2', 'PS3', 'SE', 'FS1', 'TS2']])

y_pred_prob_cooler = boosting_cooler.predict_proba(X_test[['CE', 'CP', 'PS4', 'PS5', 'TS1', 'TS2', 'TS3', 'TS4']])
y_pred_prob_valve = boosting_valve.predict_proba(X_test[['PS2', 'PS3']])
y_pred_prob_pump = boosting_pump.predict_proba(X_test[['FS1', 'SE', 'PS1']])
y_pred_prob_hydraulic = boosting_hydraulic.predict_proba(X_test[['PS1', 'PS2', 'PS3', 'SE', 'FS1', 'TS2']])

# %% [markdown]
# # Evaluate the performance for each classifier

# %%
accuracy_cooler = accuracy_score(y_test['y_coolerCondition'], y_pred_cooler)
accuracy_valve = accuracy_score(y_test['y_valveCondition'], y_pred_valve)
accuracy_pump = accuracy_score(y_test['y_pumpLeak'], y_pred_pump)
accuracy_hydraulic = accuracy_score(y_test['y_hydraulicAcc'], y_pred_hydraulic)

# %% [markdown]
# # Print results

# %%
print("Accuracy - Cooler Condition:",accuracy_cooler)
print("Accuracy - Valve Condition:",accuracy_valve)
print("Accuracy - Pump Leak:",accuracy_pump)
print("Accuracy - Hydraulic Acc:",accuracy_hydraulic)
# Out:
# Accuracy - Cooler Condition: 0.9977324263038548
# Accuracy - Valve Condition: 0.7573696145124716
# Accuracy - Pump Leak: 0.9841269841269841
# Accuracy - Hydraulic Acc: 0.9070294784580499

# %% [markdown]
# # Generate classification reports and confusion matrices

# %%
report_cooler = classification_report(y_test['y_coolerCondition'], y_pred_cooler)
matrix_cooler = confusion_matrix(y_test['y_coolerCondition'], y_pred_cooler)

report_valve = classification_report(y_test['y_valveCondition'], y_pred_valve)
matrix_valve = confusion_matrix(y_test['y_valveCondition'], y_pred_valve)

report_pump = classification_report(y_test['y_pumpLeak'], y_pred_pump)
matrix_pump = confusion_matrix(y_test['y_pumpLeak'], y_pred_pump)

report_hydraulic = classification_report(y_test['y_hydraulicAcc'], y_pred_hydraulic)
matrix_hydraulic = confusion_matrix(y_test['y_hydraulicAcc'], y_pred_hydraulic)

# %% [markdown]
# # Print classification reports and confusion matrices

# %%
print("Classification Report - Cooler Condition:")
print(report_cooler)
print("Confusion Matrix - Cooler Condition:")
print(matrix_cooler)
print("\n")

print("Classification Report - Valve Condition:")
print(report_valve)
print("Confusion Matrix - Valve Condition:")
print(matrix_valve)
print("\n")

print("Classification Report - Pump Leak:")
print(report_pump)
print("Confusion Matrix - Pump Leak:")
print(matrix_pump)
print("\n")

print("Classification Report - Hydraulic Acc:")
print(report_hydraulic)
print("Confusion Matrix - Hydraulic Acc:")
print(matrix_hydraulic)
print("\n")
# Out:
# Classification Report - Cooler Condition:
#               precision    recall  f1-score   support
#
#            3       1.00      1.00      1.00       156
#           20       0.99      1.00      1.00       145
#          100       1.00      0.99      1.00       140
#
#     accuracy                           1.00       441
#    macro avg       1.00      1.00      1.00       441
# weighted avg       1.00      1.00      1.00       441
#
# Confusion Matrix - Cooler Condition:
# [[156   0   0]
#  [  0 145   0]
#  [  0   1 139]]
#
#
# Classification Report - Valve Condition:
#               precision    recall  f1-score   support
#
#           73       0.77      0.73      0.75        70
#           80       0.64      0.58      0.60        73
#           90       0.67      0.43      0.53        72
#          100       0.80      0.93      0.86       226
#
#     accuracy                           0.76       441
#    macro avg       0.72      0.67      0.68       441
# ...

# %% [markdown]
# # Function to plot confusion matrix as heatmap

# %%
def plot_confusion_matrix_heatmap(matrix, title):
    plt.figure(figsize=(8, 6))
    sns.heatmap(matrix, annot=True, fmt='d', cmap='Blues')
    plt.title(title)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

# %% [markdown]
# # Plot confusion matrices as heatmaps

# %%
plot_confusion_matrix_heatmap(matrix_cooler, title='Cooler Condition Confusion Matrix')
plot_confusion_matrix_heatmap(matrix_valve, title='Valve Condition Confusion Matrix')
plot_confusion_matrix_heatmap(matrix_pump, title='Pump Leak Confusion Matrix')
plot_confusion_matrix_heatmap(matrix_hydraulic, title='Hydraulic Acc Confusion Matrix')

# %% [markdown]
# # Compute ROC AUC Score

# %%
roc_auc_score_cooler = roc_auc_score(y_test['y_coolerCondition'], y_pred_prob_cooler, multi_class='ovr')
roc_auc_score_valve = roc_auc_score(y_test['y_valveCondition'], y_pred_prob_valve, multi_class='ovr')
roc_auc_score_pump = roc_auc_score(y_test['y_pumpLeak'], y_pred_prob_pump, multi_class='ovr')
roc_auc_score_hydraulic = roc_auc_score(y_test['y_hydraulicAcc'], y_pred_prob_hydraulic, multi_class='ovr')

print("ROC AUC Score - Cooler Condition:",roc_auc_score_cooler)
print("ROC AUC Score - Valve Condition:",roc_auc_score_valve)
print("ROC AUC Score - Pump Leak:",roc_auc_score_pump)
print("ROC AUC Score - Hydraulic Acc:",roc_auc_score_hydraulic)
# Out:
# ROC AUC Score - Cooler Condition: 0.9988555415880999
# ROC AUC Score - Valve Condition: 0.9171002804694388
# ROC AUC Score - Pump Leak: 0.9990271948374639
# ROC AUC Score - Hydraulic Acc: 0.983564756434891

# %% [markdown]
# # Plot ROC Curve

# %%
class_cooler=np.unique(y_test['y_coolerCondition'])
fpr_cooler = dict()
tpr_cooler = dict()
roc_auc_cooler = dict()
for i in range(class_cooler.shape[0]):
    fpr_cooler[i], tpr_cooler[i], _ = roc_curve(y_test['y_coolerCondition'], y_pred_prob_cooler[:,i], pos_label=class_cooler[i])
    roc_auc_cooler[i] = auc(fpr_cooler[i], tpr_cooler[i])
    plt.plot(fpr_cooler[i], tpr_cooler[i], linestyle='--',label='ROC curve of class {0} (area = {1:f})'.format(class_cooler[i], roc_auc_cooler[i]))
plt.plot([0, 1], [0, 1], 'k--',label='Random Forest')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Cooler Condition')
plt.legend(loc="lower right")
plt.show()

# %%
class_valve=np.unique(y_test['y_valveCondition'])
fpr_valve = dict()
tpr_valve = dict()
roc_auc_valve = dict()
for i in range(class_valve.shape[0]):
    fpr_valve[i], tpr_valve[i], _ = roc_curve(y_test['y_valveCondition'], y_pred_prob_valve[:,i], pos_label=class_valve[i])
    roc_auc_valve[i] = auc(fpr_valve[i], tpr_valve[i])
    plt.plot(fpr_valve[i], tpr_valve[i], linestyle='--',label='ROC curve of class {0} (area = {1:f})'.format(class_valve[i], roc_auc_valve[i]))
plt.plot([0, 1], [0, 1], 'k--',label='Random Forest')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Valve Condition')
plt.legend(loc="lower right")
plt.show()

# %%
class_pump=np.unique(y_test['y_pumpLeak'])
fpr_pump = dict()
tpr_pump = dict()
roc_auc_pump = dict()
for i in range(class_pump.shape[0]):
    fpr_pump[i], tpr_pump[i], _ = roc_curve(y_test['y_pumpLeak'], y_pred_prob_pump[:,i], pos_label=class_pump[i])
    roc_auc_pump[i] = auc(fpr_pump[i], tpr_pump[i])
    plt.plot(fpr_pump[i], tpr_pump[i], linestyle='--',label='ROC curve of class {0} (area = {1:f})'.format(class_pump[i], roc_auc_pump[i]))
plt.plot([0, 1], [0, 1], 'k--',label='Random Forest')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Pump Leak')
plt.legend(loc="lower right")
plt.show()

# %%
class_hydraulic=np.unique(y_test['y_hydraulicAcc'])
fpr_hydraulic = dict()
tpr_hydraulic = dict()
roc_auc_hydraulic = dict()
for i in range(class_hydraulic.shape[0]):
    fpr_hydraulic[i], tpr_hydraulic[i], _ = roc_curve(y_test['y_hydraulicAcc'], y_pred_prob_hydraulic[:,i], pos_label=class_hydraulic[i])
    roc_auc_hydraulic[i] = auc(fpr_hydraulic[i], tpr_hydraulic[i])
    plt.plot(fpr_hydraulic[i], tpr_hydraulic[i], linestyle='--',label='ROC curve of class {0} (area = {1:f})'.format(class_hydraulic[i], roc_auc_hydraulic[i]))
plt.plot([0, 1], [0, 1], 'k--',label='Random Forest')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Hydraulic Acc')
plt.legend(loc="lower right")
plt.show()
